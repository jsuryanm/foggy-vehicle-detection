# %%
import gdown
import os

# %%
# upload your gdrive url
url = "https://drive.google.com/file/d/1uVb59BEtNN9Ece0oxYMq_czUIy80p9VK/view?usp=sharing"

# %%
os.chdir('../')

# %%
file_id = url.split("/")[-2]
print(file_id)
# Out:
# 1uVb59BEtNN9Ece0oxYMq_czUIy80p9VK

# %%
prefix = "https://drive.google.com/uc?/export=download&id="
gdown.download(prefix+file_id, "data/foggy_vehicle_data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1uVb59BEtNN9Ece0oxYMq_czUIy80p9VK
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1uVb59BEtNN9Ece0oxYMq_czUIy80p9VK&confirm=t&uuid=9d1d6e13-cc03-4739-950c-d67f85babfb1
# To: c:\Users\rsurs\OneDrive\Documents\foggy-vehicle-detection\data\foggy_vehicle_data.zip
# 100%|██████████| 57.9M/57.9M [00:00<00:00, 93.2MB/s]
# 'data/foggy_vehicle_data.zip'
